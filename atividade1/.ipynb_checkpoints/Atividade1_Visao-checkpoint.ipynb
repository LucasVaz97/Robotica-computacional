# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print ("OpenCV Version : %s "% cv2.__version__)
# Out:
# OpenCV Version : 3.3.0

# %% [markdown]
# # Equalização de histograma

# %% [markdown]
# ## O histograma original nao aproveita bem a faixa de cores, pois ele fica entre 0 e 50 quando poderia ir de 0 a 250

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240, 320, 3)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)
print(rintin_gray.min())
rintin_gray=rintin_gray-8
print(rintin_gray.max())
rintin_gray=rintin_gray*(255/50)
# Out:
# 8
# 50

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Equalize o histograma de maneira que a cumulativa seja uma função linear na diagonal do gráfico
# 3. Plote a imagem desenhada

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](hall_box_battery1.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e a bateria azul?
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui

# %% [markdown]
# ## Nao e possivel identificar a figura vermelha pu a figura azul utilizando  o histograma

# %%
fon = cv2.imread("hall_box_battery1.jpg")

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'g')
plt.hist(fon.flatten(),256,[0,256], color = 'b')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
fon = cv2.cvtColor(fon, cv2.COLOR_BGR2RGB)
for i in fon:
    for j in i:
        if j[0] >150 and j[1]<=30 and j[2]<=30:
            j[0]=255
            j[1]=255
            j[2]=255

# %%
plt.imshow(fon,vmin=0,vmax=255)

# %%
fon = cv2.imread("hall_box_battery1.jpg")
fon = cv2.cvtColor(fon, cv2.COLOR_BGR2RGB)

HSV_box = cv2.cvtColor(fon, cv2.COLOR_BGR2HSV)
mask = cv2.inRange(HSV_box, np.array([110,120,50]), np.array([130,255,255]))
plt.imshow(fon)
plt.show()
plt.imshow(mask, cmap='Greys_r')
plt.show()
